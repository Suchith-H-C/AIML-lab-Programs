# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn import datasets

# Load the Iris dataset
iris = datasets.load_iris()
X = iris.data
y = iris.target

# Convert to DataFrame
df = pd.DataFrame(X, columns=iris.feature_names)
df['target'] = y

# Splitting dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# Train KNN classifier
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)

# Predictions
y_pred = knn.predict(X_test)

# Evaluate model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Print confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)

# Print correct and incorrect predictions
print("\nCorrect Predictions:")
for i in range(len(y_test)):
    if y_test[i] == y_pred[i]:
        print(f"Index {i}: True Label = {y_test[i]}, Predicted = {y_pred[i]}")

print("\nIncorrect Predictions:")
for i in range(len(y_test)):
    if y_test[i] != y_pred[i]:
        print(f"Index {i}: True Label = {y_test[i]}, Predicted = {y_pred[i]}")
# Out:
# Accuracy: 0.98
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       0.95      1.00      0.97        19
#            2       1.00      0.94      0.97        18
#
#     accuracy                           0.98        60
#    macro avg       0.98      0.98      0.98        60
# weighted avg       0.98      0.98      0.98        60
#
# Confusion Matrix:
# [[23  0  0]
#  [ 0 19  0]
#  [ 0  1 17]]
#
# Correct Predictions:
# Index 0: True Label = 1, Predicted = 1
# Index 1: True Label = 0, Predicted = 0
# Index 2: True Label = 2, Predicted = 2
# Index 3: True Label = 1, Predicted = 1
# Index 4: True Label = 1, Predicted = 1
# Index 5: True Label = 0, Predicted = 0
# Index 6: True Label = 1, Predicted = 1
# Index 7: True Label = 2, Predicted = 2
# Index 8: True Label = 1, Predicted = 1
# Index 9: True Label = 1, Predicted = 1
# Index 10: True Label = 2, Predicted = 2
# Index 11: True Label = 0, Predicted = 0
# Index 12: True Label = 0, Predicted = 0
# Index 13: True Label = 0, Predicted = 0
# Index 14: True Label = 0, Predicted = 0
# Index 15: True Label = 1, Predicted = 1
# Index 16: True Label = 2, Predicted = 2
# Index 17: True Label = 1, Predicted = 1
# Index 18: True Label = 1, Predicted = 1
# Index 19: True Label = 2, Predicted = 2
# Index 20: True Label = 0, Predicted = 0
# Index 21: True Label = 2, Predicted = 2
# Index 22: True Label = 0, Predicted = 0
# Index 23: True Label = 2, Predicted = 2
# Index 24: True Label = 2, Predicted = 2
# Index 25: True Label = 2, Predicted = 2
# Index 26: True Label = 2, Predicted = 2
# Index 27: True Label = 2, Predicted = 2
# Index 28: True Label = 0, Predicted = 0
# Index 29: True Label = 0, Predicted = 0
# Index 30: True Label = 0, Predicted = 0
# Index 31: True Label = 0, Predicted = 0
# Index 32: True Label = 1, Predicted = 1
# Index 33: True Label = 0, Predicted = 0
# Index 34: True Label = 0, Predicted = 0
# Index 35: True Label = 2, Predicted = 2
# Index 36: True Label = 1, Predicted = 1
# Index 37: True Label = 0, Predicted = 0
# Index 38: True Label = 0, Predicted = 0
# Index 39: True Label = 0, Predicted = 0
# Index 40: True Label = 2, Predicted = 2
# Index 41: True Label = 1, Predicted = 1
# Index 42: True Label = 1, Predicted = 1
# Index 43: True Label = 0, Predicted = 0
# Index 44: True Label = 0, Predicted = 0
# Index 45: True Label = 1, Predicted = 1
# Index 47: True Label = 2, Predicted = 2
# Index 48: True Label = 1, Predicted = 1
# Index 49: True Label = 2, Predicted = 2
# Index 50: True Label = 1, Predicted = 1
# Index 51: True Label = 2, Predicted = 2
# Index 52: True Label = 1, Predicted = 1
# Index 53: True Label = 0, Predicted = 0
# Index 54: True Label = 2, Predicted = 2
# Index 55: True Label = 1, Predicted = 1
# Index 56: True Label = 0, Predicted = 0
# Index 57: True Label = 0, Predicted = 0
# Index 58: True Label = 0, Predicted = 0
# Index 59: True Label = 1, Predicted = 1
#
# Incorrect Predictions:
# Index 46: True Label = 2, Predicted = 1
